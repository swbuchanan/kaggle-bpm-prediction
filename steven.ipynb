# %%
# Code you have previously used to load data
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# Path of the file to read
data_file = 'train.csv'
song_data = pd.read_csv(data_file)

song_data.head()
# Out:
#    id  RhythmScore  AudioLoudness  VocalContent  AcousticQuality  \
# 0   0     0.603610      -7.636942      0.023500         0.000005
# 1   1     0.639451     -16.267598      0.071520         0.444929
# 2   2     0.514538     -15.953575      0.110715         0.173699
# 3   3     0.734463      -1.357000      0.052965         0.001651
# 4   4     0.532968     -13.056437      0.023500         0.068687
#
#    InstrumentalScore  LivePerformanceLikelihood  MoodScore  TrackDurationMs  \
# 0           0.000001                   0.051385   0.409866      290715.6450
# 1           0.349414                   0.170522   0.651010      164519.5174
# 2           0.453814                   0.029576   0.423865      174495.5667
# 3           0.159717                   0.086366   0.278745      225567.4651
# 4           0.000001                   0.331345   0.477769      213960.6789
#
#      Energy  BeatsPerMinute
# 0  0.826267       147.53020
# 1  0.145400       136.15963
# 2  0.624667        55.31989
# ...

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import   # or Ridge, RandomForestRegressor, etc.

X = song_data.drop(columns=['id', 'BeatsPerMinute'])
y = song_data['BeatsPerMinute']

# optional: shuffle for better CV splits
cv = KFold(n_splits=5, shuffle=True, random_state=1234)

model = TheilSenRegressor()
scores = cross_val_score(model, X, y, cv=cv, scoring='neg_root_mean_squared_error')  # or 'neg_mean_squared_error'

print("R² per fold:", scores)
print("Mean R²:", scores.mean())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 cv = KFold(n_splits=5, shuffle=True, random_state=1234)
#      10 model = TheilSenRegressor()
# ---> 11 scores = cross_val_score(model, X, y, cv=cv, scoring='neg_root_mean_squared_error')  # or 'neg_mean_squared_error'
#      13 print("R² per fold:", scores)
#      14 print("Mean R²:", scores.mean())
#
# File ~/.pyenv/versions/.env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
# ...
